# %% [markdown]
# # Local Debug Run
#
# This notebook imports the `src` module directly to run the training pipeline.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))

from src.utils import load_config, get_device, get_logger, print_system_info
from src.train import run_single_experiment

print_system_info()
device = get_device()
logger = get_logger()

config = load_config('../configs/config.yaml')
config['run']['debug'] = True

run_single_experiment('wow_04', ['srm_tlu_cnn'], config, device, logger)
